# %% [markdown]
# ![image.png](attachment:90df5c8f-6340-4657-b08f-963bcbea5e48.png)

# %% [markdown]
# ![image.png](attachment:f065fd19-9e8b-4f31-bdaa-16d5f863beb9.png)

# %% [markdown]
# ![image.png](attachment:fe654876-db24-4fe9-90fe-f987aee5cafb.png)

# %% [markdown]
# ![image.png](attachment:114a54f1-cafd-4ec8-ac81-198ff5c2f7df.png)

# %% [markdown]
# ![image.png](attachment:e6e5b751-5985-4fe8-8d34-6b9879226f9b.png)

# %% [markdown]
# ![image.png](attachment:c6de7b9f-6203-4567-a19e-c84d67961c8f.png)

# %% [markdown]
# ![image.png](attachment:7f936cf2-5a84-45d0-98c5-5f91f49e8d35.png)

# %% [markdown]
# ![image.png](attachment:6642de13-451a-4cf5-be25-fe0d50b86c3d.png)

# %% [markdown]
# ![image.png](attachment:55f69307-c042-4d73-80c2-2f4170d7a954.png)

# %% [markdown]
# ![ChatGPT Image Jul 8, 2026, 07_00_09 PM.png](attachment:c420a697-27eb-47f7-bf84-d656aa6e9535.png)

# %%
import numpy as np
import pandas as pd
