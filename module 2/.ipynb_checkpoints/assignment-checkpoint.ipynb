# %%
import pandas as pd
df = pd.read_csv('ass.csv')
df.head()
# Out:
#    Unnamed: 0  SEQNUMC  SEQNUMHH  PDAT    PROVWT_D     RDDWT_D  STRATUM  YEAR  \
# 0           1   128521     12852     2         NaN  235.916956     1031  2017
# 1           2    10741      1074     2         NaN  957.353840     1068  2017
# 2           3   220011     22001     2         NaN  189.611299     1050  2017
# 3           4    86131      8613     1  675.430817  333.447418     1040  2017
# 4           5   227141     22714     1  482.617748  278.768063     1008  2017
#
#    AGECPOXR  HAD_CPOX  ...  XVRCTY2  XVRCTY3  XVRCTY4  XVRCTY5  XVRCTY6  \
# 0       NaN         2  ...                        NaN      NaN      NaN
# 1       NaN         2  ...                        NaN      NaN      NaN
# 2       NaN         2  ...                        NaN      NaN      NaN
# 3       NaN         2  ...                        NaN      NaN      NaN
# 4       NaN         2  ...                        NaN      NaN      NaN
#
#    XVRCTY7  XVRCTY8  XVRCTY9  INS_STAT2_I  INS_BREAK_I
# ...

# %%
df = df.set_index('Unnamed: 0')
df.columns = [x.lower() for x in df.columns]
df.head()
# Out:
#             seqnumc  seqnumhh  pdat    provwt_d     rddwt_d  stratum  year  \
# Unnamed: 0
# 1            128521     12852     2         NaN  235.916956     1031  2017
# 2             10741      1074     2         NaN  957.353840     1068  2017
# 3            220011     22001     2         NaN  189.611299     1050  2017
# 4             86131      8613     1  675.430817  333.447418     1040  2017
# 5            227141     22714     1  482.617748  278.768063     1008  2017
#
#             agecpoxr  had_cpox  agegrp  ...  xvrcty2  xvrcty3  xvrcty4  \
# Unnamed: 0                              ...
# 1                NaN         2       1  ...                        NaN
# 2                NaN         2       1  ...                        NaN
# 3                NaN         2       3  ...                        NaN
# 4                NaN         2       1  ...                        NaN
# 5                NaN         2       1  ...                        NaN
#
# ...

# %% [markdown]
# ![image.png](attachment:8cc4e149-0ce8-4812-93f0-f552d509ade3.png)

# %% [markdown]
# ![image.png](attachment:479452a4-5862-414a-9d52-5145e8a505c3.png)

# %%
df['educ1'].unique()
# Out:
# array([4, 3, 1, 2])

# %%
df['educ1'].dtype
# Out:
# dtype('int64')

# %%
ndf = df['educ1'].copy()
ndf = ndf.to_frame('education')
ndf = ndf.reset_index()
ndf.columns = ['index', 'education']
ndf = ndf.set_index('index')
ndf.head()
# Out:
#        education
# index
# 1              4
# 2              3
# 3              3
# 4              4
# 5              1

# %%
res = ndf.groupby('education').size().to_frame('proportion')
total = len(res)
res['proportion'] = res['proportion'] / total
res
# Out:
#            proportion
# education
# 1              726.00
# 2             1226.50
# 3             1749.75
# 4             3414.00

# %%
d = {}
d['less than high school'] =726.00
d['high school'] = 1226.50
d['more than high school but not college'] = 1749.75
d['college'] = 3414.00

print(d)
# Out:
# {'less than high school': 726.0, 'high school': 1226.5, 'more than high school but not college': 1749.75, 'college': 3414.0}

# %% [markdown]
# ![image.png](attachment:13106c15-6819-4014-9b72-43596a29b401.png)

# %% [markdown]
# ![image.png](attachment:ca6f17dc-f566-4949-99bc-9dd3775f5535.png)

# %% [markdown]
# ![image.png](attachment:598f3dd9-fb2f-458d-90ad-9206541b1b25.png)

# %%
ndf = df[['cbf_01', 'p_numflu']]
ndf = ndf.reset_index()
ndf.columns = ['child','bf','vc']
ndf = ndf.set_index('child')
ndf = ndf.fillna(0)
ndf.head()
# Out:
#        bf   vc
# child
# 1       1  0.0
# 2       2  0.0
# 3       2  0.0
# 4       2  3.0
# 5       1  0.0

# %%
ndf.nunique()
# Out:
# bf    4
# vc    7
# dtype: int64

# %%
ndf['bf'].unique()
# Out:
# array([ 1,  2, 99, 77])

# %%
ndf['vc'].unique()
# Out:
# array([0., 3., 2., 1., 4., 5., 6.])

# %%
ndf = ndf[ndf['bf'] <= 2]
ndf['bf'].unique()
# Out:
# array([1, 2])

# %%
ndf['bf'] -= 1
ndf['bf'].unique()
# Out:
# array([0, 1])

# %%
ndf['bf'] = ndf['bf'].astype(bool)
ndf['bf'].unique()
# Out:
# array([False,  True])

# %%
ndf.head()
# Out:
#           bf   vc
# child
# 1      False  0.0
# 2       True  0.0
# 3       True  0.0
# 4       True  3.0
# 5      False  0.0

# %%
ndf['vc'] = ndf['vc'].astype(bool)
ndf['vc'].unique()
# Out:
# array([False,  True])

# %%
ndf.head()
# Out:
#           bf     vc
# child
# 1      False  False
# 2       True  False
# 3       True  False
# 4       True   True
# 5      False  False

# %%
res = ndf.groupby('bf').size().to_frame('average')
res['average'] = res['average'] / total
res
# Out:
#        average
# bf
# False  6065.25
# True   1021.25

# %% [markdown]
# ![image.png](attachment:797dd436-bc4c-4223-8231-cc910b691e24.png)
