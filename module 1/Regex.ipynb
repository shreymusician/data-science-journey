# %% [markdown]
# ### Regex for Data Cleaning

# %%
# Regex - Regular Expression, used to clean textual data. We can write our own regex expression
import re

# To find pattern string at starting 
main = "This is a Good Day :)"
if re.match("This",main):
    print("Yes")

# To find anywhere in the main string
if re.search("Good",main):
    print("Yes")
# Out:
# Yes
# Yes

# %%
# Just like checking using Conditionals, we can Segment a String.
# Tokenizing -> Splitting a string into substrings based on patterns.
# Tokenizing is used heavily in NLP

# Using split()
main = "Shreyas is a Coder. Shreyas is also a Musician. Shreyas has a great life."
print(re.split('Shreyas',main))

# Using findall()
print(re.findall('Shreyas', main))
# Out:
# ['', ' is a Coder. ', ' is also a Musician. ', ' has a great life.']
# ['Shreyas', 'Shreyas', 'Shreyas']

# %%
# ^ -> Starting | $ -> Ending
re.search("^Shreyas", main)
re.search("a great life.$", main)
# Out:
# <re.Match object; span=(0, 7), match='Shreyas'>

# %% [markdown]
# ### Patterns and Character Classes

# %%
grades = "AABBBAABBBBBBAAABCCCCCAACABDCC"

# Single Grade
print(re.findall("B",grades))

# Multiple Grades using Set Operator (Square Brackets)
print(re.findall("[BC]",grades))

# Combination of Grades
print(re.findall("[B][A-C]",grades))
print(re.findall("[A][B][C]",grades))

# Using Pipeline operator
print(re.findall("AB|AC",grades))

# Except some character
print(re.findall("[^B]",grades))

# Special Query
print(re.findall("^[^A]",grades)) # returns all characters as a list that starts with not 'A'
# Out:
# ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']
# ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'C', 'C']
# ['BB', 'BA', 'BB', 'BB', 'BB', 'BC']
# ['ABC']
# ['AB', 'AB', 'AB', 'AC', 'AB']
# ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'C', 'C', 'C', 'C', 'C', 'A', 'A', 'C', 'A', 'D', 'C', 'C']
# []

# %% [markdown]
# ### Quantifiers

# %%
# Format -> e{m,n}
print(re.findall("A{2,5}",grades))

# if provided one value in braces, taken as both values
print(re.findall("B{3}",grades))

# de-streak
print(re.findall("A{1,5}B{1,5}C{1,5}",grades))
# Out:
# ['AA', 'AA', 'AAA', 'AA']
# ['BBB', 'BBB', 'BBB']
# ['AAABCCCCC']

# %%
#shorthands --> *-0/more ?-1/more +-1/more
with open('datasets/ferpa.txt') as file:
    wiki = file.read()
wiki
# Out:
# 'Overview[edit]\nFERPA gives parents access to their child\'s education records, an opportunity to seek to have the records amended, and some control over the disclosure of information from the records. With several exceptions, schools must have a student\'s consent prior to the disclosure of education records after that student is 18 years old. The law applies only to educational agencies and institutions that receive funds under a program administered by the U.S. Department of Education.\n\nOther regulations under this act, effective starting January 3, 2012, allow for greater disclosures of personal and directory student identifying information and regulate student IDs and e-mail addresses.[2] For example, schools may provide external companies with a student\'s personally identifiable information without the student\'s consent.[2]\n\nExamples of situations affected by FERPA include school employees divulging information to anyone other than the student about the student\'s grades
# ...

# %%
re.findall("[a-zA-z]{1,100}\[edit\]", wiki)
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %%
re.findall("[\w]{1,100}\[edit\]", wiki) # \w -> any word \s -> whitespace
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %%
re.findall("[\w]*\[edit\]", wiki) # shorthand
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %%
re.findall("[\w ]*\[edit\]", wiki) # improvement
# Out:
# ['Overview[edit]',
#  'Access to public records[edit]',
#  'Student medical records[edit]']

# %%
rlist = re.findall("[\w ]*\[edit\]", wiki) # pretty print

for text in rlist:
    print(re.split("[\[]",text)[0])
# Out:
# Overview
# Access to public records
# Student medical records

# %% [markdown]
# #### Shorthand Regexes
# \w -> any word <br>
# \s -> whitespace <br>
# \. -> single character not newline <br>
# \d -> digit
